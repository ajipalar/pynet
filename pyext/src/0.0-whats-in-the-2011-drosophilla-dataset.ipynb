# %%
import pandas as pd
from pathlib import Path

# %%
# What is in the dataset?

dpath = "../../data/raw/apms/20110527_CELL_145_5_AnalysisOfTheHumanDendogenousCoregulatorComplexome/"
f1 = "mmc1.xls"
f2 = "mmc2.xls"

dpath = Path(dpath)

# %%
pd.read_excel(dpath / f2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pd.read_excel(dpath / f2)
#
# File ~/anaconda3/envs/pynet/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/pynet/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
