# %%
import multiprocessing as mp
print(f"Number of processors:{mp.cpu_count()}")
# Out:
# Number of processors:24

# %%
import numpy as np
from time import time
# Prepare data
np.random.RandomState(100)
arr = np.random.randint(0, 10, size=[200000, 5])
data = arr.tolist()
data[:5]
# Out:
# [[9, 0, 3, 4, 8],
#  [7, 1, 7, 3, 8],
#  [6, 6, 9, 1, 0],
#  [0, 1, 1, 2, 6],
#  [4, 6, 8, 5, 0]]

# %%
def howmany_within_range(row, minimum, maximum):
    """Returns how many numbers lie within `maximum` and `minimum` in a given `row`"""
    count = 0
    for n in row:
        if minimum <= n <= maximum:
            count = count + 1
    return count

results = []
for row in data:
    results.append(howmany_within_range(row, minimum=4, maximum=8))

print(results[:10])
# Out:
# [2, 3, 2, 1, 4, 3, 1, 3, 5, 4]

# %%
pool = mp.Pool(mp.cpu_count())
# Out:
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-71:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-66:
# Process ForkPoolWorker-64:
# Process ForkPoolWorker-65:
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-68:
# Process ForkPoolWorker-69:
# Process ForkPoolWorker-72:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-58:
# Process ForkPoolWorker-63:
# Process ForkPoolWorker-62:
# Process ForkPoolWorker-67:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-70:
# Process ForkPoolWorker-60:
# Process ForkPoolWorker-61:
# Process ForkPoolWorker-55:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-51:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-50:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 366, in get
#     res = self._reader.recv_bytes()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/aji/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt

# %%
results = [pool.apply(howmany_within_range, args=(row, 4, 8)) for row in data]
pool.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_680737/3076680575.py in <module>
# ----> 1 results = [pool.apply(howmany_within_range, args=(row, 4, 8)) for row in data]
#       2 pool.close()
#
# /tmp/ipykernel_680737/3076680575.py in <listcomp>(.0)
# ----> 1 results = [pool.apply(howmany_within_range, args=(row, 4, 8)) for row in data]
#       2 pool.close()
#
# ~/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py in apply(self, func, args, kwds)
#     355         Pool must be running.
#     356         '''
# --> 357         return self.apply_async(func, args, kwds).get()
#     358
#     359     def map(self, func, iterable, chunksize=None):
#
# ~/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~/anaconda3/envs/pynetp/lib/python3.9/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~/anaconda3/envs/pynetp/lib/python3.9/threading.py in wait(self, timeout)
#     572             signaled = self._flag
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#     576
#
# ~/anaconda3/envs/pynetp/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:
